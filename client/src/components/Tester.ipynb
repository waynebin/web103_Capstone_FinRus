# %%
# %pip install yfinance pandas
# Out:
# Requirement already satisfied: yfinance in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (0.2.66)
# Requirement already satisfied: pandas in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from yfinance) (2.3.4)
# Requirement already satisfied: requests>=2.31 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from yfinance) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from yfinance) (4.14.2)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from yfinance) (6.33.0)
# Requirement already satisfied: websockets>=13.0 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.10.5)
# Requirement already satisfied: pycparser in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: six>=1.5 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from requests>=2.31->yfinance) (2.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd
import time
from datetime import datetime, timedelta
def fetch_historical_data(ticker,start_date,end_date,retries=3,delay=1):
    """Fetch historical stock data from Yahoo Finance.
    ARGS:
        ticker (str): Stock ticker symbol.
        start_date (str): Start date in 'YYYY-MM-DD' format.
        end_date (str): End date in 'YYYY-MM-DD' format.
        RETURNS:
        pd.DataFrame: DataFrame containing historical stock data."""
    
    for attempt in range(retries):
        try:
           #getting stock data
           stock=yf.Ticker(ticker)
           #Fetch historical data
           hist=stock.history(start=start_date,end=end_date)

           # check if data is empty
           if hist.empty:
               print(f"No data found for {ticker} between {start_date} and {end_date}.")
               if attempt < retries -1:
                   print(f"Retrying...({attempt + 1}/{retries})")
                   time.sleep(delay)
                   continue
               else:
                   None
           return hist
        
        except Exception as e:
            print(f"❌ Error fetching {ticker} data: {str(e)}")
            
            if attempt < retries - 1:
                print(f"Retrying in {delay} seconds...")
                time.sleep(delay)
            else:
                print(f"All retry attempts failed. Generating sample data for {ticker}")
                return None
    
    return None

# %%
fetch_historical_data('AAPL', '2023-11-01', '2024-11-30')
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-11-01 00:00:00-04:00  169.177288  172.372854  168.306663  172.115631
# 2023-11-02 00:00:00-04:00  173.649140  175.885045  173.589782  175.677292
# 2023-11-03 00:00:00-04:00  172.382789  174.935291  171.502276  174.767090
# 2023-11-06 00:00:00-05:00  174.499967  177.517445  174.331781  177.319580
# 2023-11-07 00:00:00-05:00  177.270114  180.495375  177.062361  179.881989
# ...                               ...         ...         ...         ...
# 2024-11-22 00:00:00-05:00  227.033174  229.681201  227.033174  228.835022
# 2024-11-25 00:00:00-05:00  230.417878  232.199812  228.705621  231.821518
# 2024-11-26 00:00:00-05:00  232.279457  234.509377  232.279457  234.001663
# 2024-11-27 00:00:00-05:00  233.414333  234.628841  232.757301  233.872253
# 2024-11-29 00:00:00-05:00  233.752786  236.739279  232.916572  236.261444
#
#                              Volume  Dividends  Stock Splits
# Date
# 2023-11-01 00:00:00-04:00  56934900        0.0           0.0
# 2023-11-02 00:00:00-04:00  77334800        0.0           0.0
# 2023-11-03 00:00:00-04:00  79829200        0.0           0.0
# 2023-11-06 00:00:00-05:00  63841300        0.0           0.0
# 2023-11-07 00:00:00-05:00  70530000        0.0           0.0
# ...                             ...        ...           ...
# 2024-11-22 00:00:00-05:00  38168300        0.0           0.0
# 2024-11-25 00:00:00-05:00  90152800        0.0           0.0
# 2024-11-26 00:00:00-05:00  45986200        0.0           0.0
# 2024-11-27 00:00:00-05:00  33498400        0.0           0.0
# 2024-11-29 00:00:00-05:00  28481400        0.0           0.0
#
# [272 rows x 7 columns]

# %%
# Test with 2024 data
result = fetch_historical_data('AAPL', '2024-10-25', '2024-10-30')
print(f"Result type: {type(result)}")
if result is not None:
    print(f"Shape: {result.shape}")
    print(result.head(2))
else:
    print("No data returned")
# Out:
# Result type: <class 'pandas.core.frame.DataFrame'>
# Shape: (3, 7)
#                                  Open        High         Low       Close  \
# Date
# 2024-10-25 00:00:00-04:00  228.454277  231.914797  228.285230  230.114929
# 2024-10-28 00:00:00-04:00  232.014242  233.416339  231.248547  232.093781
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-10-25 00:00:00-04:00  38802300        0.0           0.0
# 2024-10-28 00:00:00-04:00  36087100        0.0           0.0

# %%
# %pip install Flask

import sys
import os

# Try to locate a parent folder that contains the 'Data' package and add it to sys.path
def ensure_data_package_in_path(start_dir=None):
	if start_dir is None:
		start_dir = os.getcwd()
	cur = os.path.abspath(start_dir)
	root = os.path.abspath(os.sep)
	while True:
		if os.path.isdir(os.path.join(cur, 'Data')):
			if cur not in sys.path:
				sys.path.insert(0, cur)
			return True
		if cur == root:
			return False
		cur = os.path.dirname(cur)

# First attempt from current working directory; if not found try a few levels up relative to this notebook location
if not ensure_data_package_in_path():
	# common repo layout: notebook may live several directories deep; try a couple of parents
	tried = False
	for up in range(1, 5):
		candidate = os.path.abspath(os.path.join(os.getcwd(), *(['..'] * up)))
		if ensure_data_package_in_path(candidate):
			tried = True
			break
	if not tried and not ensure_data_package_in_path():
		raise ModuleNotFoundError(
			"Could not find 'Data' directory in parent folders. Ensure the 'Data' package (with HistoricalDataAPI.py) "
			"exists in a parent directory of this notebook."
		)

from Data.HistoricalDataAPI import app

app.run(debug=True, host='0.0.0.0', port=5000)
# Out:
# Requirement already satisfied: Flask in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (3.1.2)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from Flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from Flask) (8.3.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from Flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from Flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from Flask) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from Flask) (3.1.3)
# Requirement already satisfied: colorama in c:\users\duway\onedrive\documentos\github\web103_capstone_finrus\.venv\lib\site-packages (from click>=8.1.3->Flask) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 31
#      29 			break
#      30 	if not tried and not ensure_data_package_in_path():
# ---> 31 		raise ModuleNotFoundError(
#      32 			"Could not find 'Data' directory in parent folders. Ensure the 'Data' package (with HistoricalDataAPI.py) "
#      33 			"exists in a parent directory of this notebook."
#      34 		)
#      36 from Data.HistoricalDataAPI import app
#      38 app.run(debug=True, host='0.0.0.0', port=5000)
#
# ModuleNotFoundError: Could not find 'Data' directory in parent folders. Ensure the 'Data' package (with HistoricalDataAPI.py) exists in a parent directory of this notebook.

# %% [markdown]
# ## Test Complete Data Pipeline
#
# Now let's test the complete pipeline including JSON conversion

# %%
# Test 1: Import and test YahooData module
import sys
sys.path.insert(0, r'C:\Users\duway\OneDrive\Documentos\GitHub\web103_Capstone_FinRus\server\Data')

from YahooData import fetch_historical_data, fetch_multiple_tickers, get_recent_data
import json

# Test single ticker
print("=" * 60)
print("Test 1: Single Ticker Fetch")
print("=" * 60)

result = fetch_historical_data('AAPL', '2024-10-25', '2024-10-30')

if result and result.get('metadata', {}).get('success'):
    print(f"✅ SUCCESS!")
    print(f"   Ticker: {result['ticker']}")
    print(f"   Data points: {result['metadata']['data_points']}")
    print(f"   Cached: {result['metadata'].get('cached', False)}")
    print(f"\n📊 Sample data (first 2 days):")
    for day in result['data'][:2]:
        print(f"   {day['Date']}: Close=${day['Close']}, Volume={day['Volume']:,}")
    
    # Test JSON serialization
    json_str = json.dumps(result, indent=2)
    print(f"\n✅ JSON serialization successful ({len(json_str):,} chars)")
else:
    print("❌ FAILED:", result.get('metadata', {}).get('error', 'Unknown error') if result else 'No result')

print("\n" + result['ticker'] if result else "")
# Out:
# 2025-11-11 14:59:48,917 - YahooData - INFO - Fetching data for AAPL from 2024-10-25 to 2024-10-30
# 2025-11-11 14:59:48,942 - YahooData - INFO - 💾 Cached data for AAPL
# 2025-11-11 14:59:48,944 - YahooData - INFO - ✅ Successfully fetched 3 data points for AAPL
# ============================================================
# Test 1: Single Ticker Fetch
# ============================================================
# ✅ SUCCESS!
#    Ticker: AAPL
#    Data points: 3
#    Cached: False
#
# 📊 Sample data (first 2 days):
#    2024-10-25: Close=$230.11, Volume=38,802,300
#    2024-10-28: Close=$232.09, Volume=36,087,100
#
# ✅ JSON serialization successful (989 chars)
#
# AAPL

# %%
# Test 2: Multiple Tickers
print("=" * 60)
print("Test 2: Multiple Tickers Fetch")
print("=" * 60)

tickers = ['AAPL', 'GOOGL', 'MSFT']
results = fetch_multiple_tickers(tickers, '2024-10-28', '2024-10-30')

success_count = 0
for ticker, result in results.items():
    if result and result.get('metadata', {}).get('success'):
        success_count += 1
        print(f"✅ {ticker}: {result['metadata']['data_points']} data points")
    else:
        error = result.get('metadata', {}).get('error', 'Unknown') if result else 'No result'
        print(f"❌ {ticker}: {error}")

print(f"\n📊 Success Rate: {success_count}/{len(tickers)} tickers")
# Out:
# 2025-11-11 15:00:35,930 - YahooData - INFO - Processing ticker 1/3: AAPL
# 2025-11-11 15:00:35,931 - YahooData - INFO - Fetching data for AAPL from 2024-10-28 to 2024-10-30
# 2025-11-11 15:00:35,931 - YahooData - INFO - Fetching data for AAPL from 2024-10-28 to 2024-10-30
# ============================================================
# Test 2: Multiple Tickers Fetch
# ============================================================
# 2025-11-11 15:00:36,207 - YahooData - INFO - 💾 Cached data for AAPL
# 2025-11-11 15:00:36,209 - YahooData - INFO - ✅ Successfully fetched 2 data points for AAPL
# 2025-11-11 15:00:36,209 - YahooData - INFO - ✅ Successfully fetched 2 data points for AAPL
# 2025-11-11 15:00:36,311 - YahooData - INFO - Processing ticker 2/3: GOOGL
# 2025-11-11 15:00:36,313 - YahooData - INFO - Fetching data for GOOGL from 2024-10-28 to 2024-10-30
# 2025-11-11 15:00:36,311 - YahooData - INFO - Processing ticker 2/3: GOOGL
# 2025-11-11 15:00:36,313 - YahooData - INFO - Fetching data for GOOGL from 2024-10-28 to 2024-10-30
# 2025-11-11 15:00:36,624 - YahooData - INFO - 💾 Cached data for GOOGL
# 2025-11-11 15:00:36,624 - YahooData - INFO - ✅ Successfully fetched 2 data points for GOOGL
# 2025-11-11 15:00:36,624 - YahooData - INFO - 💾 Cached data for GOOGL
# 2025-11-11 15:00:36,624 - YahooData - INFO - ✅ Successfully fetched 2 data points for GOOGL
# 2025-11-11 15:00:36,727 - YahooData - INFO - Processing ticker 3/3: MSFT
# 2025-11-11 15:00:36,729 - YahooData - INFO - Fetching data for MSFT from 2024-10-28 to 2024-10-30
# 2025-11-11 15:00:36,727 - YahooData - INFO - Processing ticker 3/3: MSFT
# 2025-11-11 15:00:36,729 - YahooData - INFO - Fetching data for MSFT from 2024-10-28 to 2024-10-30
# 2025-11-11 15:00:36,995 - YahooData - INFO - 💾 Cached data for MSFT
# 2025-11-11 15:00:36,996 - YahooData - INFO - ✅ Successfully fetched 2 data points for MSFT
# 2025-11-11 15:00:36,995 - YahooData - INFO - 💾 Cached data for MSFT
# 2025-11-11 15:00:36,996 - YahooData - INFO - ✅ Successfully fetched 2 data points for MSFT
# ✅ AAPL: 2 data points
# ✅ GOOGL: 2 data points
# ✅ MSFT: 2 data points
#
# 📊 Success Rate: 3/3 tickers

# %%
# Test 3: Start Flask API Server in Notebook
print("=" * 60)
print("Test 3: Flask API Server")
print("=" * 60)
print("Starting Flask API server...")
print("Once running, you can test endpoints at:")
print("  - http://localhost:5000/api/health")
print("  - http://localhost:5000/api/stock/AAPL?days_back=7")
print("  - http://localhost:5000/api/stock/multiple?tickers=AAPL,GOOGL")
print("\nPress Ctrl+C to stop the server")
print("=" * 60)

# Import and run Flask app
import sys
sys.path.insert(0, r'C:\Users\duway\OneDrive\Documentos\GitHub\web103_Capstone_FinRus\server\Data')

from HistoricalDataAPI import app

# Run the Flask app
# Note: This will block the notebook cell until stopped
app.run(debug=True, host='127.0.0.1', port=5000, use_reloader=False)
